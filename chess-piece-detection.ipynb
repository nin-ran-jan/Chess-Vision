# %%
# %%capture
# import gdown
# gdown.download("https://drive.google.com/file/d/154jMGBWMmsKkZjAP_OcU9V-OOZN30L8u/view?usp=share_link", fuzzy=True)

# %%
# !unzip "Chess Pieces.v24-416x416_aug.yolov5pytorch.zip"
# Out:
# Archive:  Chess Pieces.v24-416x416_aug.yolov5pytorch.zip
# replace README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 15637 (delta 123), reused 173 (delta 100), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.58 MiB | 10.17 MiB/s, done.
# Resolving deltas: 100% (10652/10652), done.

# %%
import torch
import os

# %%
# YOLOV5-L
# %cd yolov5
# !python train.py --img 416 --batch 16 --epochs 150 --data ../data.yaml --weights yolov5l.pt --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /raid/home/niranjan20090/CV/yolov5
# train: weights=yolov5l.pt, cfg=, data=../data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:0 (A100-SXM4-40GB, 40537MiB)
#
# ...

# %%
# %cd yolov5
# !python train.py --img 416 --batch 16 --epochs 150 --data ../data.yaml --weights yolov5s.pt --cache
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /raid/home/niranjan20090/CV/yolov5
# train: weights=yolov5s.pt, cfg=, data=../data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:0 (A100-SXM4-40GB, 40537MiB)
#
# ...

# %%
# %cd yolov5
# !python train.py --img 416 --batch 16 --epochs 150 --data ../data-gray.yaml --weights yolov5s.pt --cache --device 1 --project exp-gray/train
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /raid/home/niranjan20090/CV/yolov5
# train: weights=yolov5s.pt, cfg=, data=../data-gray.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=1, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=exp-gray/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:1 (A100-SXM4-40GB, 40537MiB)
#
# ...

# %%
import cv2

# %%
# %cd yolov5
# !python detect.py --weights runs/train/exp/weights/best.pt --line-thickness 1 --img 416 --conf 0.1 --source ../infer/ --save-txt
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /raid/home/niranjan20090/CV/yolov5
# detect: weights=['runs/train/exp/weights/best.pt'], source=../infer/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:0 (A100-SXM4-40GB, 40537MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46172898 parameters, 0 gradients, 107.8 GFLOPs
# ...

# %%
# !python val.py --weights runs/train/exp_150_og_dataset/weights/best.pt --data ../data.yaml --img 416
# Out:
# val: data=../data.yaml, weights=['runs/train/exp_150_og_dataset/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:0 (A100-SXM4-40GB, 40537MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# val: Scanning /raid/home/niranjan20090/CV/dataset/test/labels... 29 images, 1 ba
# val: New cache created: /raid/home/niranjan20090/CV/dataset/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all         29        376      0.973      0.987      0.978      0.797
# ...

# %%
# %cd yolov5
# !python detect.py --weights exp-gray/train/exp/weights/best.pt --line-thickness 1 --img 416 --conf 0.1 --source ../infer-gray/ --save-txt
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /raid/home/niranjan20090/CV/yolov5
# detect: weights=['exp-gray/train/exp/weights/best.pt'], source=../infer-gray/, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /raid/home/niranjan20090/CV/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.16 torch-2.0.0 CUDA:0 (A100-SXM4-40GB, 40537MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7045186 parameters, 0 gradients, 15.9 GFLOPs
# libpng warning: iCCP: profile 'ICC Profile': 'RGB ': RGB color space not permitted on grayscale PNG
# ...

# %%
import glob
from IPython.display import Image, display

for imageName in glob.glob('./runs/detect/exp6/*'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")

# %%
python val.py --weights yolov5s.pt --data coco128.yaml --img 640
